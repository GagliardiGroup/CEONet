# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs --host localhost --port=8081
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 8081 (pid 3088843), started 0:46:05 ago. (Use '!kill 3088843' to kill it.)
#       <iframe id="tensorboard-frame-535e735e25514431" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-535e735e25514431");
#           const url = new URL("/", window.location);
#           const port = 8081;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Making Figures

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import torch_geometric as pyg
import glob
from torch.utils.data import Dataset, DataLoader
from dsk.pickle import dump_pkl, load_pkl

epochs = pd.read_csv("results/reg2_epochs.csv")
mae = pd.read_csv("results/reg2_loss.csv")
plt.plot(mae["Step"],mae["Value"])
plt.ylim(0.1,0.5)
# Out:
# (0.1, 0.5)

# %%
mae.iloc[-1]
# Out:
# Wall time    1.713192e+09
# Step         2.104100e+04
# Value        4.011282e-01
# Name: 125, dtype: float64
